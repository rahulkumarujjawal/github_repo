# %%
# %sql
create table TATA(
    id INT PRIMARY KEY,
    name VARCHAR(100),
    age INT,
    salary DECIMAL(10,2),
    email VARCHAR(100),
    department VARCHAR(100)
);

INSERT INTO tata (id, name, age, salary, email, department) VALUES
(1, 'Rahul Sharma', 28, 55000, 'rahul.sharma@example.com', 'IT'),
(2, 'Nikita Singh', 25, 60000, 'nikita.singh@example.com', 'HR'),
(3, 'Manish Kumar', 30, 75000, 'manish.kumar@example.com', 'Finance'),
(4, 'Vikash Gupta', 32, 80000, 'vikash.gupta@example.com', 'IT'),
(5, 'Pooja Mishra', 27, 65000, 'pooja.mishra@example.com', 'Marketing'),

-- Duplicate department (HR)
(6, 'Priya Das', 24, 50000, 'priya.das@example.com', 'HR'),

-- Duplicate salary
(7, 'Rohit Verma', 29, 60000, 'rohit.verma@example.com', 'Sales'),
(8, 'Sneha Patil', 26, 60000, 'sneha.patil@example.com', 'Marketing'),

-- Duplicate name
(9, 'Rahul Sharma', 31, 70000, 'rahul.s2@example.com', 'Finance'),

-- Duplicate department (IT)
(10, 'Amit Kumar', 33, 55000, 'amit.kumar@example.com', 'IT'),

-- Duplicate salary
(11, 'Aisha Khan', 22, 55000, 'aisha.khan@example.com', 'Sales'),

-- Duplicate salary and dept
(12, 'Deepak Jha', 34, 80000, 'deepak.jha@example.com', 'IT'),

(13, 'Sonam Yadav', 28, 90000, 'sonam.yadav@example.com', 'Finance'),

-- Duplicate name
(14, 'Nikita Singh', 26, 75000, 'nikita.s2@example.com', 'Finance'),

-- Duplicate department (Marketing)
(15, 'Kiran Mehta', 29, 62000, 'kiran.mehta@example.com', 'Marketing'),

-- Duplicate salary
(16, 'Vineet Rao', 35, 70000, 'vineet.rao@example.com', 'Sales'),

(17, 'Harshita Roy', 27, 85000, 'harshita.roy@example.com', 'HR'),

-- Duplicate department IT
(18, 'Gaurav Malhotra', 30, 65000, 'gaurav.m@example.com', 'IT'),

-- Duplicate department HR
(19, 'Anushka Jain', 24, 50000, 'anushka.jain@example.com', 'HR'),

-- Duplicate salary and duplicate department
(20, 'Ravi Shankar', 33, 55000, 'ravi.shankar@example.com', 'IT');

select * from tata;
-- select max(salary) from  tata_emp_02;

# %%
# %sql
select * from tata 
where salary =55000 and
department = "HR";

# %%
# %sql
select count(salary) from tata

# %%
# %sql
select distinct department   as dept
from tata
